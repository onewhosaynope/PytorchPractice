# %%
import torch 
from torch import nn
import torch.nn.functional as F


import numpy as np

# %%
with open('poems.txt', 'r', encoding='utf8') as f:
    text = f.read()
    
    

all_characters = set(text)

# nums --> letters
decoder = dict(enumerate(all_characters))
# letters --> nums
encoder = {char: index for index, char in decoder.items()}

# build list of all encoded chars for text
encoded_text = np.array([encoder[char] for char in text])

# %%
def one_hot_encoder(encoded_text, num_unique_chars):
    
    # encoded_text --> batch of encoded text
    # num_unique_chars --> len(set(text))
    
    one_hot = np.zeros((encoded_text.size, num_unique_chars))
    one_hot = one_hot.astype(np.float32)
    one_hot[np.arange(one_hot.shape[0]), encoded_text.flatten()] = 1.0
    one_hot = one_hot.reshape((*encoded_text.shape, num_unique_chars))
    
    return one_hot

# %%
def generate_batches(encoded_text, samp_per_batch=10, seq_len=50):
    
    # X : encoded text of length seq_len
    # [0, 1, 2]
    # [1, 2, 3]
    
    # Y : encoded text shifted by one
    
    # [1, 2, 3]
    # [2, 3, 4]
    
    # how many chars per batch?
    char_per_batch = samp_per_batch * seq_len 
    # how many batches can we make, given the len of encoded text?
    num_batches_available = int(len(encoded_text) / char_per_batch)
    # cut off the end of the encoded text, that won't fit evenly into a batch
    encoded_text = encoded_text[ : num_batches_available * char_per_batch]
    # reshape the encoded text
    encoded_text = encoded_text.reshape((samp_per_batch, -1))
    
    for n in range(0, encoded_text.shape[1], seq_len):
        
        x = encoded_text[ : , n : n + seq_len]
        # zeros array to the same shape as x
        y = np.zeros_like(x)
        
        try:
            y[:, :-1] = x[:, 1:]
            y[:, -1] = encoded_text[:, n+seq_len]
            
        except:
            y[:, :-1] = x[:, 1:]
            y[:, -1] = encoded_text[:, 0]
            
        yield x, y

# %%
class CharModel(nn.Module):
    
    def __init__(self, all_chars, num_hidden=256, num_layers=4,drop_prob=0.5,use_gpu=False):
        
        
        # SET UP ATTRIBUTES
        super().__init__()
        self.drop_prob = drop_prob
        self.num_layers = num_layers
        self.num_hidden = num_hidden
        self.use_gpu = use_gpu
        
        #CHARACTER SET, ENCODER, and DECODER
        self.all_chars = all_chars
        self.decoder = dict(enumerate(all_chars))
        self.encoder = {char: ind for ind,char in decoder.items()}
        
        
        self.lstm = nn.LSTM(len(self.all_chars), num_hidden, num_layers, dropout=drop_prob, batch_first=True)
        
        self.dropout = nn.Dropout(drop_prob)
        
        self.fc_linear = nn.Linear(num_hidden, len(self.all_chars))
      
    
    def forward(self, x, hidden):
                  
        lstm_output, hidden = self.lstm(x, hidden)
        
        drop_output = self.dropout(lstm_output)
        drop_output = drop_output.contiguous().view(-1, self.num_hidden)
        
        final_out = self.fc_linear(drop_output)

        return final_out, hidden
    
    
    def hidden_state(self, batch_size):
        '''
        Used as separate method to account for both GPU and CPU users.
        '''
        
        if self.use_gpu:
            
            hidden = (torch.zeros(self.num_layers,batch_size,self.num_hidden).cuda(),
                     torch.zeros(self.num_layers,batch_size,self.num_hidden).cuda())
        else:
            hidden = (torch.zeros(self.num_layers,batch_size,self.num_hidden),
                     torch.zeros(self.num_layers,batch_size,self.num_hidden))
        
        return hidden

# %%
model = CharModel(all_chars=all_characters,
                 num_hidden=512,
                 num_layers=3,
                 drop_prob=0.5,
                 use_gpu=True)

# %%
total_param = []

for p in model.parameters():
    total_param.append(int(p.numel()))
    
total_param
# Out:
# [333824,
#  1048576,
#  2048,
#  2048,
#  1048576,
#  1048576,
#  2048,
#  2048,
#  1048576,
#  1048576,
#  2048,
#  2048,
#  83456,
#  163]

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

train_percent = 0.9
train_index = int(len(encoded_text) * train_percent)

train_data = encoded_text[:train_index]
val_data = encoded_text[train_index:]

# %%
# Variables

epochs = 40
batch_size = 228
seq_len = 150
tracker = 0
num_char = max(encoded_text) + 1

previous_loss = 100
min_loss = 100

# %%
# Set model to train
model.train()


# Check to see if using GPU
if model.use_gpu:
    model.cuda()

for i in range(epochs):
    
    hidden = model.hidden_state(batch_size)
    
    
    for x,y in generate_batches(train_data,batch_size,seq_len):
        
        tracker += 1
        
        # One Hot Encode incoming data
        x = one_hot_encoder(x,num_char)
        
        # Convert Numpy Arrays to Tensor
        
        inputs = torch.from_numpy(x)
        targets = torch.from_numpy(y)
        
        # Adjust for GPU if necessary
        
        if model.use_gpu:
            
            inputs = inputs.cuda()
            targets = targets.cuda()
            
        # Reset Hidden State
        # If we dont' reset we would backpropagate through all training history
        hidden = tuple([state.data for state in hidden])
        
        model.zero_grad()
        
        lstm_output, hidden = model.forward(inputs,hidden)
        loss = criterion(lstm_output,targets.view(batch_size*seq_len).long())
        
        loss.backward()
        
        # POSSIBLE EXPLODING GRADIENT PROBLEM!
        # LET"S CLIP JUST IN CASE
        nn.utils.clip_grad_norm_(model.parameters(),max_norm=5)
        
        optimizer.step()
        
        
        
        ###################################
        ### CHECK ON VALIDATION SET ######
        #################################
        
        if tracker % 25 == 0:
            
            val_hidden = model.hidden_state(batch_size)
            val_losses = []
            model.eval()
            
            for x,y in generate_batches(val_data,batch_size,seq_len):
                
                # One Hot Encode incoming data
                x = one_hot_encoder(x, num_char)
                

                # Convert Numpy Arrays to Tensor

                inputs = torch.from_numpy(x)
                targets = torch.from_numpy(y)

                # Adjust for GPU if necessary

                if model.use_gpu:

                    inputs = inputs.cuda()
                    targets = targets.cuda()
                    
                # Reset Hidden State
                # If we dont' reset we would backpropagate through 
                # all training history
                val_hidden = tuple([state.data for state in val_hidden])
                
                lstm_output, val_hidden = model.forward(inputs,val_hidden)
                val_loss = criterion(lstm_output,targets.view(batch_size*seq_len).long())
                val_losses.append(val_loss.item())
            
            # Reset to training model after val for loop
            model.train()
    
            current_loss = val_loss.item()
        
            print(f"Epoch: {i} Step: {tracker} \nCurrent Validation Loss: {current_loss} \nPrevious Loss: {previous_loss}")

            if (current_loss < previous_loss):
                if (current_loss < min_loss):
                    print('Error decreased!')
                    torch.save(model.state_dict(), 'min_hidden512_layers3_poems.net')
                    print('Saved model.')
                    min_loss = current_loss
                else:
                    print('Error increased!')
                
            previous_loss = val_loss.item()
            print()
# Out:
# Epoch: 0 Step: 25
# Current Validation Loss: 3.4704153537750244
# Previous Loss: 100
# Error decreased!
# Saved model.
#
# Epoch: 0 Step: 50
# Current Validation Loss: 3.47161602973938
# Previous Loss: 3.4704153537750244
#
# Epoch: 0 Step: 75
# Current Validation Loss: 3.471928834915161
# Previous Loss: 3.47161602973938
#
# Epoch: 0 Step: 100
# Current Validation Loss: 3.47171688079834
# Previous Loss: 3.471928834915161
# Error increased!
#
# Epoch: 1 Step: 125
# Current Validation Loss: 3.4436721801757812
# Previous Loss: 3.47171688079834
# Error decreased!
# Saved model.
#
# Epoch: 1 Step: 150
# Current Validation Loss: 3.319533586502075
# Previous Loss: 3.4436721801757812
# Error decreased!
# Saved model.
#
# Epoch: 1 Step: 175
# Current Validation Loss: 3.076944351196289
# Previous Loss: 3.319533586502075
# Error decreased!
# Saved model.
#
# Epoch: 1 Step: 200
# Current Validation Loss: 2.9640023708343506
# Previous Loss: 3.076944351196289
# Error decreased!
# Saved model.
#
# Epoch: 2 Step: 225
# Current Validation Loss: 2.911484718322754
# Previous Loss: 2.9640023708343506
# Error decreased!
# Saved model.
#
# Epoch: 2 Step: 250
# Current Validation Loss: 2.855376958847046
# Previous Loss: 2.911484718322754
# Error decreased!
# Saved model.
#
# Epoch: 2 Step: 275
# Current Validation Loss: 2.792559862136841
# Previous Loss: 2.855376958847046
# Error decreased!
# Saved model.
#
# Epoch: 2 Step: 300
# Current Validation Loss: 2.7385990619659424
# Previous Loss: 2.792559862136841
# Error decreased!
# Saved model.
#
# Epoch: 3 Step: 325
# Current Validation Loss: 2.699366569519043
# Previous Loss: 2.7385990619659424
# Error decreased!
# Saved model.
#
# Epoch: 3 Step: 350
# Current Validation Loss: 2.670654773712158
# Previous Loss: 2.699366569519043
# Error decreased!
# Saved model.
#
# Epoch: 3 Step: 375
# Current Validation Loss: 2.636221170425415
# Previous Loss: 2.670654773712158
# Error decreased!
# Saved model.
#
# Epoch: 3 Step: 400
# Current Validation Loss: 2.6069719791412354
# Previous Loss: 2.636221170425415
# Error decreased!
# Saved model.
#
# Epoch: 4 Step: 425
# Current Validation Loss: 2.57804012298584
# Previous Loss: 2.6069719791412354
# Error decreased!
# Saved model.
#
# Epoch: 4 Step: 450
# Current Validation Loss: 2.556856155395508
# Previous Loss: 2.57804012298584
# Error decreased!
# Saved model.
#
# Epoch: 4 Step: 475
# Current Validation Loss: 2.5304086208343506
# Previous Loss: 2.556856155395508
# Error decreased!
# Saved model.
#
# Epoch: 4 Step: 500
# Current Validation Loss: 2.5037925243377686
# Previous Loss: 2.5304086208343506
# Error decreased!
# Saved model.
#
# Epoch: 5 Step: 525
# Current Validation Loss: 2.4911599159240723
# Previous Loss: 2.5037925243377686
# Error decreased!
# Saved model.
#
# Epoch: 5 Step: 550
# Current Validation Loss: 2.4569969177246094
# Previous Loss: 2.4911599159240723
# Error decreased!
# Saved model.
#
# Epoch: 5 Step: 575
# Current Validation Loss: 2.4383339881896973
# Previous Loss: 2.4569969177246094
# Error decreased!
# Saved model.
#
# Epoch: 5 Step: 600
# Current Validation Loss: 2.4144530296325684
# Previous Loss: 2.4383339881896973
# Error decreased!
# Saved model.
#
# Epoch: 6 Step: 625
# Current Validation Loss: 2.4029488563537598
# Previous Loss: 2.4144530296325684
# Error decreased!
# Saved model.
#
# Epoch: 6 Step: 650
# Current Validation Loss: 2.378288745880127
# Previous Loss: 2.4029488563537598
# Error decreased!
# Saved model.
#
# Epoch: 6 Step: 675
# Current Validation Loss: 2.362565040588379
# Previous Loss: 2.378288745880127
# Error decreased!
# Saved model.
#
# Epoch: 6 Step: 700
# Current Validation Loss: 2.341536045074463
# Previous Loss: 2.362565040588379
# Error decreased!
# Saved model.
#
# Epoch: 7 Step: 725
# Current Validation Loss: 2.3265933990478516
# Previous Loss: 2.341536045074463
# Error decreased!
# Saved model.
#
# Epoch: 7 Step: 750
# Current Validation Loss: 2.309617519378662
# Previous Loss: 2.3265933990478516
# Error decreased!
# Saved model.
#
# Epoch: 7 Step: 775
# Current Validation Loss: 2.2949366569519043
# Previous Loss: 2.309617519378662
# Error decreased!
# Saved model.
#
# Epoch: 7 Step: 800
# Current Validation Loss: 2.2802083492279053
# Previous Loss: 2.2949366569519043
# Error decreased!
# Saved model.
#
# Epoch: 8 Step: 825
# Current Validation Loss: 2.2664103507995605
# Previous Loss: 2.2802083492279053
# Error decreased!
# Saved model.
#
# Epoch: 8 Step: 850
# Current Validation Loss: 2.2546236515045166
# Previous Loss: 2.2664103507995605
# Error decreased!
# Saved model.
#
# Epoch: 8 Step: 875
# Current Validation Loss: 2.2412283420562744
# Previous Loss: 2.2546236515045166
# Error decreased!
# Saved model.
#
# Epoch: 8 Step: 900
# Current Validation Loss: 2.2274281978607178
# Previous Loss: 2.2412283420562744
# Error decreased!
# Saved model.
#
# Epoch: 9 Step: 925
# Current Validation Loss: 2.216052293777466
# Previous Loss: 2.2274281978607178
# Error decreased!
# Saved model.
#
# Epoch: 9 Step: 950
# Current Validation Loss: 2.2058160305023193
# Previous Loss: 2.216052293777466
# Error decreased!
# Saved model.
#
# Epoch: 9 Step: 975
# Current Validation Loss: 2.1954879760742188
# Previous Loss: 2.2058160305023193
# Error decreased!
# Saved model.
#
# Epoch: 9 Step: 1000
# Current Validation Loss: 2.180668830871582
# Previous Loss: 2.1954879760742188
# Error decreased!
# Saved model.
#
# Epoch: 10 Step: 1025
# Current Validation Loss: 2.173863649368286
# Previous Loss: 2.180668830871582
# Error decreased!
# Saved model.
#
# Epoch: 10 Step: 1050
# Current Validation Loss: 2.160029888153076
# Previous Loss: 2.173863649368286
# Error decreased!
# Saved model.
#
# Epoch: 10 Step: 1075
# Current Validation Loss: 2.152416706085205
# Previous Loss: 2.160029888153076
# Error decreased!
# Saved model.
#
# Epoch: 10 Step: 1100
# Current Validation Loss: 2.140502452850342
# Previous Loss: 2.152416706085205
# Error decreased!
# Saved model.
#
# Epoch: 11 Step: 1125
# Current Validation Loss: 2.1322154998779297
# Previous Loss: 2.140502452850342
# Error decreased!
# Saved model.
#
# Epoch: 11 Step: 1150
# Current Validation Loss: 2.122356653213501
# Previous Loss: 2.1322154998779297
# Error decreased!
# Saved model.
#
# Epoch: 11 Step: 1175
# Current Validation Loss: 2.1200785636901855
# Previous Loss: 2.122356653213501
# Error decreased!
# Saved model.
#
# Epoch: 11 Step: 1200
# Current Validation Loss: 2.1091885566711426
# Previous Loss: 2.1200785636901855
# Error decreased!
# Saved model.
#
# Epoch: 12 Step: 1225
# Current Validation Loss: 2.1029341220855713
# Previous Loss: 2.1091885566711426
# Error decreased!
# Saved model.
#
# Epoch: 12 Step: 1250
# Current Validation Loss: 2.089688301086426
# Previous Loss: 2.1029341220855713
# Error decreased!
# Saved model.
#
# Epoch: 12 Step: 1275
# Current Validation Loss: 2.0819966793060303
# Previous Loss: 2.089688301086426
# Error decreased!
# Saved model.
#
# Epoch: 12 Step: 1300
# Current Validation Loss: 2.073333263397217
# Previous Loss: 2.0819966793060303
# Error decreased!
# Saved model.
#
# Epoch: 13 Step: 1325
# Current Validation Loss: 2.0657992362976074
# Previous Loss: 2.073333263397217
# Error decreased!
# Saved model.
#
# Epoch: 13 Step: 1350
# Current Validation Loss: 2.057830333709717
# Previous Loss: 2.0657992362976074
# Error decreased!
# Saved model.
#
# Epoch: 13 Step: 1375
# Current Validation Loss: 2.05416202545166
# Previous Loss: 2.057830333709717
# Error decreased!
# Saved model.
#
# Epoch: 13 Step: 1400
# Current Validation Loss: 2.0434954166412354
# Previous Loss: 2.05416202545166
# Error decreased!
# Saved model.
#
# Epoch: 14 Step: 1425
# Current Validation Loss: 2.036306619644165
# Previous Loss: 2.0434954166412354
# Error decreased!
# Saved model.
#
# Epoch: 14 Step: 1450
# Current Validation Loss: 2.03049373626709
# Previous Loss: 2.036306619644165
# Error decreased!
# Saved model.
#
# Epoch: 14 Step: 1475
# Current Validation Loss: 2.026817798614502
# Previous Loss: 2.03049373626709
# Error decreased!
# Saved model.
#
# Epoch: 14 Step: 1500
# Current Validation Loss: 2.0194623470306396
# Previous Loss: 2.026817798614502
# Error decreased!
# Saved model.
#
# Epoch: 15 Step: 1525
# Current Validation Loss: 2.0110130310058594
# Previous Loss: 2.0194623470306396
# Error decreased!
# Saved model.
#
# Epoch: 15 Step: 1550
# Current Validation Loss: 2.009573459625244
# Previous Loss: 2.0110130310058594
# Error decreased!
# Saved model.
#
# Epoch: 15 Step: 1575
# Current Validation Loss: 2.000748634338379
# Previous Loss: 2.009573459625244
# Error decreased!
# Saved model.
#
# Epoch: 15 Step: 1600
# Current Validation Loss: 1.9964253902435303
# Previous Loss: 2.000748634338379
# Error decreased!
# Saved model.
# Epoch: 16 Step: 1625
# Current Validation Loss: 1.9904263019561768
# Previous Loss: 1.9964253902435303
# Error decreased!
# Saved model.
#
# Epoch: 16 Step: 1650
# Current Validation Loss: 1.9878791570663452
# Previous Loss: 1.9904263019561768
# Error decreased!
# Saved model.
#
# Epoch: 16 Step: 1675
# Current Validation Loss: 1.980930209159851
# Previous Loss: 1.9878791570663452
# Error decreased!
# Saved model.
#
# Epoch: 16 Step: 1700
# Current Validation Loss: 1.968349814414978
# Previous Loss: 1.980930209159851
# Error decreased!
# Saved model.
#
# Epoch: 17 Step: 1725
# Current Validation Loss: 1.980191707611084
# Previous Loss: 1.968349814414978
#
# Epoch: 17 Step: 1750
# Current Validation Loss: 1.9687196016311646
# Previous Loss: 1.980191707611084
# Error increased!
#
# Epoch: 17 Step: 1775
# Current Validation Loss: 1.9614866971969604
# Previous Loss: 1.9687196016311646
# Error decreased!
# Saved model.
#
# Epoch: 17 Step: 1800
# Current Validation Loss: 1.9551105499267578
# Previous Loss: 1.9614866971969604
# Error decreased!
# Saved model.
#
# Epoch: 18 Step: 1825
# Current Validation Loss: 1.9517133235931396
# Previous Loss: 1.9551105499267578
# Error decreased!
# Saved model.
#
# Epoch: 18 Step: 1850
# Current Validation Loss: 1.943899393081665
# Previous Loss: 1.9517133235931396
# Error decreased!
# Saved model.
#
# Epoch: 18 Step: 1875
# Current Validation Loss: 1.9399744272232056
# Previous Loss: 1.943899393081665
# Error decreased!
# Saved model.
#
# Epoch: 18 Step: 1900
# Current Validation Loss: 1.9336652755737305
# Previous Loss: 1.9399744272232056
# Error decreased!
# Saved model.
#
# Epoch: 19 Step: 1925
# Current Validation Loss: 1.9309747219085693
# Previous Loss: 1.9336652755737305
# Error decreased!
# Saved model.
#
# Epoch: 19 Step: 1950
# Current Validation Loss: 1.9471933841705322
# Previous Loss: 1.9309747219085693
#
# Epoch: 19 Step: 1975
# Current Validation Loss: 1.9230799674987793
# Previous Loss: 1.9471933841705322
# Error decreased!
# Saved model.
#
# Epoch: 19 Step: 2000
# Current Validation Loss: 1.9148937463760376
# Previous Loss: 1.9230799674987793
# Error decreased!
# Saved model.
#
# Epoch: 20 Step: 2025
# Current Validation Loss: 1.9164706468582153
# Previous Loss: 1.9148937463760376
#
# Epoch: 20 Step: 2050
# Current Validation Loss: 1.9117298126220703
# Previous Loss: 1.9164706468582153
# Error decreased!
# Saved model.
#
# Epoch: 20 Step: 2075
# Current Validation Loss: 1.9109166860580444
# Previous Loss: 1.9117298126220703
# Error decreased!
# Saved model.
#
# Epoch: 20 Step: 2100
# Current Validation Loss: 1.8997070789337158
# Previous Loss: 1.9109166860580444
# Error decreased!
# Saved model.
#
# Epoch: 21 Step: 2125
# Current Validation Loss: 1.91077721118927
# Previous Loss: 1.8997070789337158
#
# Epoch: 21 Step: 2150
# Current Validation Loss: 1.897813081741333
# Previous Loss: 1.91077721118927
# Error decreased!
# Saved model.
#
# Epoch: 21 Step: 2175
# Current Validation Loss: 1.890730857849121
# Previous Loss: 1.897813081741333
# Error decreased!
# Saved model.
#
# Epoch: 21 Step: 2200
# Current Validation Loss: 1.8856490850448608
# Previous Loss: 1.890730857849121
# Error decreased!
# Saved model.
#
# Epoch: 22 Step: 2225
# Current Validation Loss: 1.8833805322647095
# Previous Loss: 1.8856490850448608
# Error decreased!
# Saved model.
#
# Epoch: 22 Step: 2250
# Current Validation Loss: 1.884082317352295
# Previous Loss: 1.8833805322647095
#
# Epoch: 22 Step: 2275
# Current Validation Loss: 1.8818672895431519
# Previous Loss: 1.884082317352295
# Error decreased!
# Saved model.
#
# Epoch: 22 Step: 2300
# Current Validation Loss: 1.8741599321365356
# Previous Loss: 1.8818672895431519
# Error decreased!
# Saved model.
#
# Epoch: 23 Step: 2325
# Current Validation Loss: 1.8746626377105713
# Previous Loss: 1.8741599321365356
#
# Epoch: 23 Step: 2350
# Current Validation Loss: 1.8716472387313843
# Previous Loss: 1.8746626377105713
# Error decreased!
# Saved model.
#
# Epoch: 23 Step: 2375
# Current Validation Loss: 1.8675256967544556
# Previous Loss: 1.8716472387313843
# Error decreased!
# Saved model.
#
# Epoch: 23 Step: 2400
# Current Validation Loss: 1.8674544095993042
# Previous Loss: 1.8675256967544556
# Error decreased!
# Saved model.
#
# Epoch: 24 Step: 2425
# Current Validation Loss: 1.8615561723709106
# Previous Loss: 1.8674544095993042
# Error decreased!
# Saved model.
#
# Epoch: 24 Step: 2450
# Current Validation Loss: 1.8586711883544922
# Previous Loss: 1.8615561723709106
# Error decreased!
# Saved model.
#
# Epoch: 24 Step: 2475
# Current Validation Loss: 1.8527827262878418
# Previous Loss: 1.8586711883544922
# Error decreased!
# Saved model.
#
# Epoch: 24 Step: 2500
# Current Validation Loss: 1.8506267070770264
# Previous Loss: 1.8527827262878418
# Error decreased!
# Saved model.
#
# Epoch: 24 Step: 2525
# Current Validation Loss: 1.8489561080932617
# Previous Loss: 1.8506267070770264
# Error decreased!
# Saved model.
#
# Epoch: 25 Step: 2550
# Current Validation Loss: 1.8475654125213623
# Previous Loss: 1.8489561080932617
# Error decreased!
# Saved model.
#
# Epoch: 25 Step: 2575
# Current Validation Loss: 1.8397741317749023
# Previous Loss: 1.8475654125213623
# Error decreased!
# Saved model.
#
# Epoch: 25 Step: 2600
# Current Validation Loss: 1.83876371383667
# Previous Loss: 1.8397741317749023
# Error decreased!
# Saved model.
#
# Epoch: 25 Step: 2625
# Current Validation Loss: 1.838657259941101
# Previous Loss: 1.83876371383667
# Error decreased!
# Saved model.
#
# Epoch: 26 Step: 2650
# Current Validation Loss: 1.8413994312286377
# Previous Loss: 1.838657259941101
#
# Epoch: 26 Step: 2675
# Current Validation Loss: 1.827757477760315
# Previous Loss: 1.8413994312286377
# Error decreased!
# Saved model.
#
# Epoch: 26 Step: 2700
# Current Validation Loss: 1.8300031423568726
# Previous Loss: 1.827757477760315
#
# Epoch: 26 Step: 2725
# Current Validation Loss: 1.8244825601577759
# Previous Loss: 1.8300031423568726
# Error decreased!
# Saved model.
#
# Epoch: 27 Step: 2750
# Current Validation Loss: 1.829694390296936
# Previous Loss: 1.8244825601577759
#
# Epoch: 27 Step: 2775
# Current Validation Loss: 1.8183088302612305
# Previous Loss: 1.829694390296936
# Error decreased!
# Saved model.
#
# Epoch: 27 Step: 2800
# Current Validation Loss: 1.8167542219161987
# Previous Loss: 1.8183088302612305
# Error decreased!
# Saved model.
#
# Epoch: 27 Step: 2825
# Current Validation Loss: 1.8157871961593628
# Previous Loss: 1.8167542219161987
# Error decreased!
# Saved model.
#
# Epoch: 28 Step: 2850
# Current Validation Loss: 1.8150559663772583
# Previous Loss: 1.8157871961593628
# Error decreased!
# Saved model.
#
# Epoch: 28 Step: 2875
# Current Validation Loss: 1.8135830163955688
# Previous Loss: 1.8150559663772583
# Error decreased!
# Saved model.
#
# Epoch: 28 Step: 2900
# Current Validation Loss: 1.8166459798812866
# Previous Loss: 1.8135830163955688
#
# Epoch: 28 Step: 2925
# Current Validation Loss: 1.8111392259597778
# Previous Loss: 1.8166459798812866
# Error decreased!
# Saved model.
#
# Epoch: 29 Step: 2950
# Current Validation Loss: 1.8058536052703857
# Previous Loss: 1.8111392259597778
# Error decreased!
# Saved model.
#
# Epoch: 29 Step: 2975
# Current Validation Loss: 1.8032808303833008
# Previous Loss: 1.8058536052703857
# Error decreased!
# Saved model.
#
# Epoch: 29 Step: 3000
# Current Validation Loss: 1.803636074066162
# Previous Loss: 1.8032808303833008
#
# Epoch: 29 Step: 3025
# Current Validation Loss: 1.800551414489746
# Previous Loss: 1.803636074066162
# Error decreased!
# Saved model.
#
# Epoch: 30 Step: 3050
# Current Validation Loss: 1.7986682653427124
# Previous Loss: 1.800551414489746
# Error decreased!
# Saved model.
#
# Epoch: 30 Step: 3075
# Current Validation Loss: 1.7989740371704102
# Previous Loss: 1.7986682653427124
#
# Epoch: 30 Step: 3100
# Current Validation Loss: 1.7955950498580933
# Previous Loss: 1.7989740371704102
# Error decreased!
# Saved model.
#
# Epoch: 30 Step: 3125
# Current Validation Loss: 1.7945395708084106
# Previous Loss: 1.7955950498580933
# Error decreased!
# Saved model.
#
# Epoch: 31 Step: 3150
# Current Validation Loss: 1.7920483350753784
# Previous Loss: 1.7945395708084106
# Error decreased!
# Saved model.
#
# Epoch: 31 Step: 3175
# Current Validation Loss: 1.7888832092285156
# Previous Loss: 1.7920483350753784
# Error decreased!
# Saved model.
#
# Epoch: 31 Step: 3200
# Current Validation Loss: 1.7881038188934326
# Previous Loss: 1.7888832092285156
# Error decreased!
# Saved model.
#
# Epoch: 31 Step: 3225
# Current Validation Loss: 1.78693425655365
# Previous Loss: 1.7881038188934326
# Error decreased!
# Saved model.
#
# Epoch: 32 Step: 3250
# Current Validation Loss: 1.780987024307251
# Previous Loss: 1.78693425655365
# Error decreased!
# Saved model.
# Epoch: 32 Step: 3275
# Current Validation Loss: 1.7826400995254517
# Previous Loss: 1.780987024307251
#
# Epoch: 32 Step: 3300
# Current Validation Loss: 1.779226303100586
# Previous Loss: 1.7826400995254517
# Error decreased!
# Saved model.
#
# Epoch: 32 Step: 3325
# Current Validation Loss: 1.7755992412567139
# Previous Loss: 1.779226303100586
# Error decreased!
# Saved model.
#
# Epoch: 33 Step: 3350
# Current Validation Loss: 1.7763631343841553
# Previous Loss: 1.7755992412567139
#
# Epoch: 33 Step: 3375
# Current Validation Loss: 1.770634651184082
# Previous Loss: 1.7763631343841553
# Error decreased!
# Saved model.
#
# Epoch: 33 Step: 3400
# Current Validation Loss: 1.7751214504241943
# Previous Loss: 1.770634651184082
#
# Epoch: 33 Step: 3425
# Current Validation Loss: 1.7662099599838257
# Previous Loss: 1.7751214504241943
# Error decreased!
# Saved model.
#
# Epoch: 34 Step: 3450
# Current Validation Loss: 1.767891526222229
# Previous Loss: 1.7662099599838257
#
# Epoch: 34 Step: 3475
# Current Validation Loss: 1.76295804977417
# Previous Loss: 1.767891526222229
# Error decreased!
# Saved model.
#
# Epoch: 34 Step: 3500
# Current Validation Loss: 1.76787531375885
# Previous Loss: 1.76295804977417
#
# Epoch: 34 Step: 3525
# Current Validation Loss: 1.7595531940460205
# Previous Loss: 1.76787531375885
# Error decreased!
# Saved model.
#
# Epoch: 35 Step: 3550
# Current Validation Loss: 1.756601333618164
# Previous Loss: 1.7595531940460205
# Error decreased!
# Saved model.
#
# Epoch: 35 Step: 3575
# Current Validation Loss: 1.7598921060562134
# Previous Loss: 1.756601333618164
#
# Epoch: 35 Step: 3600
# Current Validation Loss: 1.7553462982177734
# Previous Loss: 1.7598921060562134
# Error decreased!
# Saved model.
#
# Epoch: 35 Step: 3625
# Current Validation Loss: 1.755876064300537
# Previous Loss: 1.7553462982177734
#
# Epoch: 36 Step: 3650
# Current Validation Loss: 1.7491509914398193
# Previous Loss: 1.755876064300537
# Error decreased!
# Saved model.
#
# Epoch: 36 Step: 3675
# Current Validation Loss: 1.750841736793518
# Previous Loss: 1.7491509914398193
#
# Epoch: 36 Step: 3700
# Current Validation Loss: 1.7475265264511108
# Previous Loss: 1.750841736793518
# Error decreased!
# Saved model.
#
# Epoch: 36 Step: 3725
# Current Validation Loss: 1.74849271774292
# Previous Loss: 1.7475265264511108
#
# Epoch: 37 Step: 3750
# Current Validation Loss: 1.7463843822479248
# Previous Loss: 1.74849271774292
# Error decreased!
# Saved model.
#
# Epoch: 37 Step: 3775
# Current Validation Loss: 1.7493765354156494
# Previous Loss: 1.7463843822479248
#
# Epoch: 37 Step: 3800
# Current Validation Loss: 1.7441765069961548
# Previous Loss: 1.7493765354156494
# Error decreased!
# Saved model.
#
# Epoch: 37 Step: 3825
# Current Validation Loss: 1.740341067314148
# Previous Loss: 1.7441765069961548
# Error decreased!
# Saved model.
#
# Epoch: 38 Step: 3850
# Current Validation Loss: 1.7417126893997192
# Previous Loss: 1.740341067314148
#
# Epoch: 38 Step: 3875
# Current Validation Loss: 1.7412563562393188
# Previous Loss: 1.7417126893997192
# Error increased!
#
# Epoch: 38 Step: 3900
# Current Validation Loss: 1.7389346361160278
# Previous Loss: 1.7412563562393188
# Error decreased!
# Saved model.
#
# Epoch: 38 Step: 3925
# Current Validation Loss: 1.7349752187728882
# Previous Loss: 1.7389346361160278
# Error decreased!
# Saved model.
#
# Epoch: 39 Step: 3950
# Current Validation Loss: 1.7362267971038818
# Previous Loss: 1.7349752187728882
#
# Epoch: 39 Step: 3975
# Current Validation Loss: 1.7391700744628906
# Previous Loss: 1.7362267971038818
#
# Epoch: 39 Step: 4000
# Current Validation Loss: 1.739820122718811
# Previous Loss: 1.7391700744628906
#
# Epoch: 39 Step: 4025
# Current Validation Loss: 1.7293552160263062
# Previous Loss: 1.739820122718811
# Error decreased!
# Saved model.

# %%
torch.save(model.state_dict(), 'hidden512_layers3_poems.net')

# %%
def predict_next_char(model, char, hidden=None, k=1):
    
    encoded_text = model.encoder[char]
    encoded_text = np.array([[encoded_text]])
    encoded_text = one_hot_encoder(encoded_text, len(model.all_chars))
    inputs = torch.from_numpy(encoded_text)
    
    if model.use_gpu:
        inputs = inputs.cuda()
        
    hidden = tuple([state.data for state in hidden])
    
    lstm_out, hidden = model(inputs, hidden)
    
    probs = F.softmax(lstm_out, dim=1).data
    
    if model.use_gpu:
        probs = probs.cpu()
        
    probs, index_positions = probs.topk(k)
    
    index_positions = index_positions.numpy().squeeze()
    
    probs = probs.numpy().flatten()
    
    probs = probs / probs.sum()
    
    char = np.random.choice(index_positions, p=probs)
    
    return model.decoder[char], hidden

# %%
def generate_text(model, size, seed='Дело было ', k=1):
    
    if model.use_gpu:
        model.cuda()
    else:
        model.cpu()
        
    model.eval()
    
    output_chars = [c for c in seed]
    
    hidden = model.hidden_state(1)
    
    for char in seed:
        char, hidden = predict_next_char(model, char, hidden, k=k)
        
    output_chars.append(char)
    
    for i in range(size):
        
        char, hidden = predict_next_char(model, output_chars[-1], hidden, k=k)
        
        output_chars.append(char)
        
    return ''.join(output_chars)

# %%
model = CharModel(
    all_chars=all_characters,
    num_hidden=512,
    num_layers=3,
    drop_prob=0.5,
    use_gpu=True,
)

model.load_state_dict(torch.load('min_hidden512_layers3_poems.net'))
model.eval()
# Out:
# CharModel(
#   (lstm): LSTM(163, 512, num_layers=3, batch_first=True, dropout=0.5)
#   (dropout): Dropout(p=0.5)
#   (fc_linear): Linear(in_features=512, out_features=163, bias=True)
# )

# %%
print(generate_text(model, 3000, seed='Сердце ', k=4))
# Out:
# Сердце под солнцем всё всегда,
# И всё совсем не пойму совесть, подарей.
#
# Вот так всё в сон, не в сердце никакой,
# Не стало станет по сердце слёзы волной.
#
#
#
#
# В сердце наш сон, не поминалиный
# И в подруге всего не смела,
# По трупум пустоту никто,
# Чтоб в ночи наш свет все слабот,
# Но не в стране стало всегда,
# Что не ведь не смел старый поднимать.
#
# Но, собираю стрекозы солнца
# И на видно не пойзу в полях,
# На придумы полести во страха.
#
# Исполнен страшных стеров на свете,
# Проденжает, призрак с полетом,
# Все нашли со слепой собирать,
# В просто воскрепали все нежность поставал.
# Но сердце не в ней право, стану,
# Во сне, как светите ночи по другой.
#
# И не солнце постуки на дне.
# Не становись в солнцам, невозможно
# И в наших сером никуда такой
# И не стрела поступительно просто,
# И прощаются в печали собирать,
# Ведь надо слабым на собой.
#
# В ней семенице, но всё не стараться
# На курне старовал небо на поле,
# Надежды придумал солнце сладкие,
# В собой ветрах перестанет все вот,
# Под стремой в прах, собой по призрачной всю.
#
#
#
# Все стороно и настроения вся
# Признаешься мой первый долгого в стихах
# И ведем столь не смытли с тобой на солнце светит.
# И во сне всплетнит в старый превретенья,
# Под тонким подаром на старый полетель
# Но не словами в ночь просто прахом.
#
# Но, по свету старый под песней стоит платье,
# Ни не на теперь строчишь на передаркой -
# Ты ночью во мне не знала, на кудницу сложить,
# То все по твоим светлом свистым подарким.
#
#
#
#
#
#
# Всё в полный старон ночь свои полетают,
# Переследает наш свой сердце по душу.
# В полетья, с тобою с порогом слова,
# Просто на все под тонким всего слов,
# Такой надо мною, невесомо солнцем..."
#
#
#
#
# На полном своих странах в них принцесса,
# Не в сонми всегда с посениными глазами,
# Но так собако весна в солнцах.
#
# В том вознасинули в детстве свечи,
# И в таком вышел над нашей нежной
# На капельку в право страшного света...
#
#
#
#
# Ночной вечности всякой солнце
# И нет ночных дождями святой.
# Не вышу над тобой страстью
# Но стараясь всем нежной
# Надежду на сердце всё в сторонах
# И стал на воды не прислились ночью слышишь.
#
# И всё всегда не построила.
# Нас принцесса странный, путь.
#
#
#
#
# В соловейшему сердце, словно
# Весь принцесса на стихах на сердце.
# Тогда просто слепо признав,
# Ни совсем одна с тобой с тобой.
#
#
#
#
# Перед тобой на свете свет
# Во мне стихи
# И не сословили стихи
# В пространстве постоянно
# В ночь посмело в солнечных
# Новым слёз и в пустынной
# Протяжения постанет
# И подарите мой правда
# И первый в стране странный
#
# Настоящие собраться
# Правда не в стихах вернуть свет
# И в такт все получаться с стоит.
# И так нежно вспомнит
# Всегда всех наш не всё на следов
# И в совсем под собой на свой мой
# И не стала совсем не будет,
# В ней стоял наши не всегда
# В тебе на полуночный продажный.
#
#
#
#
# На как все вечная страдать
# Во стеренных странного страха.
# В стихи все в стречках на свече
# Всякой над ним предела
# И всё на ветре собрать.
#
#
#
#
# Не замечай на век на сердце
# На картину в твоей старане,
# Полночно стороной полной
# И в нам пустоты прикажет.
# В собой в тебе в прошлом над тобой,.
# В придёлом, всё сознания, страсть..
